# %% [markdown]
# # FIT5148 - Distributed Databases and Big Data
#
# # Group Assignment - Part C - Hotspot Aqua Streaming
#
# **Your Details:**
# - Name: Roopak Thiyyathuparambil Jayachandran
# - StudentID: 29567467
# - Email: rthi0002@student.monash.edu
#
# ## Introduction
#
# This file takes random input from hotspot_AQUA_streaming.csv file and pushes it to the kafka input stream.
# Methodology:
# * Converting the csv file(climate_streaming.csv) to a list of input values
# * Using random function to get value from a particular index and pushing it to the input stream

# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

# %%
climate_csv = open("hotspot_AQUA_streaming.csv","r")
climate_csv_str = climate_csv.read()

# Spliting the string with a new line considering that each line was a separate reading
climate_li = climate_csv_str.split("\n")
climate_length = len(climate_li)

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Climate'
    
    print('Publishing records from Producer 2..')
    producer = connect_kafka_producer()
    sender_id = 2
    # Dictionary to help with randomly input the stream
    dictio = {}
    while(len(dictio.keys()) != climate_length):
        # Starting from 1 since index 0 has headers
        # Generating a random number and inserting it to a dictionary to avaoid repetition
        input_index = random.randrange(1, climate_length)
        if input_index not in dictio.keys():
            dictio[input_index] = 1
        else:
            continue
        # Appending datetime and senderid to the row and passing it to consumer.
        data = climate_li[input_index] + "," + str(dt.datetime.now()) + "," + str(sender_id)
        # After creation of data, it is pushed to the stream
        publish_message(producer, topic, 'parsed', data)
        # Data is generated every 5 second
        sleep(10)
# Out:
# Publishing records from Producer 2..
# Message published successfully. Data: -37.1009,141.9666,69,45,2019-05-25 18:19:53.558754,2
# Message published successfully. Data: -36.4612,144.7775,91,80,2019-05-25 18:20:03.581565,2
# Message published successfully. Data: -36.1,143.772,65,35,2019-05-25 18:20:13.594023,2
# Message published successfully. Data: -37.5583,142.9318,71,46,2019-05-25 18:20:23.605378,2
# Message published successfully. Data: -37.4872,143.0435,81,54,2019-05-25 18:20:33.612798,2
# Message published successfully. Data: -36.759,145.179,68,52,2019-05-25 18:20:43.629895,2
# Message published successfully. Data: -35.961,141.089,83,56,2019-05-25 18:20:53.633498,2
# Message published successfully. Data: -37.5657,143.0689,100,103,2019-05-25 18:21:03.646723,2
# Message published successfully. Data: -36.9103,142.1409,73,47,2019-05-25 18:21:13.658976,2
# Message published successfully. Data: -36.714,141.1485,61,41,2019-05-25 18:21:23.673796,2
# Message published successfully. Data: -36.6986,142.7259,86,72,2019-05-25 18:21:33.683885,2
# Message published successfully. Data: -36.1569,145.6554,63,41,2019-05-25 18:21:43.687740,2
# Message published successfully. Data: -36.0818,146.5461,57,44,2019-05-25 18:21:53.692377,2
# Message published successfully. Data: -37.4357,142.7813,94,74,2019-05-25 18:22:03.710860,2
# Message published successfully. Data: -37.0434,142.001,54,41,2019-05-25 18:22:13.721137,2
# Message published successfully. Data: -37.7011,143.0393,81,54,2019-05-25 18:22:23.736023,2
# Message published successfully. Data: -37.4391,143.0293,66,43,2019-05-25 18:22:33.748751,2
