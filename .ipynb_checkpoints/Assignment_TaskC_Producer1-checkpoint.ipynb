# %% [markdown]
# # FIT5148 - Distributed Databases and Big Data
#
# # Group Assignment - Part C - Climate streaming
#
# **Your Details:**
# - Name: Roopak Thiyyathuparambil Jayachandran
# - StudentID: 29567467
# - Email: rthi0002@student.monash.edu
#
# ## Introduction
#
# This file takes random input from climate_streaming.csv file and pushes it to the kafka input stream.
# Methodology:
# * Converting the csv file(climate_streaming.csv) to a list of input values
# * Using random function to get value from a particular index and pushing it to the input stream

# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

# %%
climate_csv = open("climate_streaming.csv","r")
climate_csv_str = climate_csv.read()

# Spliting the string with a new line considering that each line was a separate reading
climate_li = climate_csv_str.split("\n")
climate_length = len(climate_li)

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Climate'
    
    print('Publishing records from Producer 1..')
    producer = connect_kafka_producer()
    sender_id = 1
    # Dictionary to help with randomly input the stream
    dictio = {}
    while(len(dictio.keys()) != climate_length):
        # Starting from 1 since index 0 has headers
        # Generating a random number and inserting it to a dictionary to avaoid repetition
        input_index = random.randrange(1, climate_length)
        if input_index not in dictio.keys():
            dictio[input_index] = 1
        else:
            continue
        # Appending datetime and senderid to the row and passing it to consumer.
        data = climate_li[input_index] + "," + str(dt.datetime.now()) + "," + str(sender_id)
        # After creation of data, it is pushed to the stream
        publish_message(producer, topic, 'parsed', data)
        # Data is generated every 5 second
        sleep(5)
# Out:
# Publishing records from Producer 1..
# Message published successfully. Data: -37.605,149.302,18,54.4,5.7,9.9, 0.00I,2019-05-25 18:20:43.258196,1
# Message published successfully. Data: -37.472,148.119,15,49.9,7.9,13, 0.01G,2019-05-25 18:20:48.269620,1
# Message published successfully. Data: -37.453,148.099,10,45.7,3.6,7, 0.01G,2019-05-25 18:20:53.278537,1
# Message published successfully. Data: -37.376,148.042,11,43.2,5.5,8, 0.00G,2019-05-25 18:20:58.285950,1
# Message published successfully. Data: -36.8264,142.6138,15,48.2,14.7,25.1, 0.43G,2019-05-25 18:21:03.290270,1
# Message published successfully. Data: -37.5915,143.0015,17,52,8.8,15, 0.00I,2019-05-25 18:21:08.301353,1
# Message published successfully. Data: -37.389,149.311,18,53,6.6,14, 0.00I,2019-05-25 18:21:13.310435,1
# Message published successfully. Data: -37.586,141.271,19,60.5,7,11.1, 0.83G,2019-05-25 18:21:18.322261,1
# Message published successfully. Data: -37.95,142.366,16,53.6,8.1,15, 0.00G,2019-05-25 18:21:23.330425,1
# Message published successfully. Data: -36.851,148.117,9,45.3,2.5,6, 0.00G,2019-05-25 18:21:28.334890,1
# Message published successfully. Data: -37.605,149.326,23,49.6,10,19, 0.00I,2019-05-25 18:21:33.350704,1
# Message published successfully. Data: -37.425,148.107,15,41.2,13.8,16.9, 0.00G,2019-05-25 18:21:38.359028,1
# Message published successfully. Data: -36.0966,142.3635,22,57,8.5,15, 0.00G,2019-05-25 18:21:43.370805,1
# Message published successfully. Data: -35.325,143.497,13,48.5,5.3,11.1, 0.08G,2019-05-25 18:21:48.379796,1
